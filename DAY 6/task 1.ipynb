# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import fetch_california_housing
import tensorflow as tf
from tensorflow import keras

data = fetch_california_housing()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = keras.Sequential([
   keras.layers.Dense(1, input_shape=(X_train.shape[1],)) 
])

model.compile(optimizer='RMSprop', loss='mse')

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20)

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend()
plt.title('Loss Curve')
plt.show()
# Out:
# Epoch 1/20
# c:\Users\dhaks\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.0741 - val_loss: 3.6670
# Epoch 2/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8196 - val_loss: 2.3369
# Epoch 3/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3038 - val_loss: 1.4428
# Epoch 4/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6805 - val_loss: 0.9039
# Epoch 5/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9033 - val_loss: 0.6915
# Epoch 6/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8481 - val_loss: 0.6234
# Epoch 7/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8629 - val_loss: 0.5784
# Epoch 8/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6293 - val_loss: 0.5526
# Epoch 9/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0073 - val_loss: 0.5376
# Epoch 10/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6741 - val_loss: 0.5291
# Epoch 11/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7649 - val_loss: 0.5271
# Epoch 12/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.1160 - val_loss: 0.5251
# Epoch 13/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6544 - val_loss: 0.5263
# Epoch 14/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.0887 - val_loss: 0.5266
# Epoch 15/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7193 - val_loss: 0.5281
# Epoch 16/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.4798 - val_loss: 0.5280
# Epoch 17/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0935 - val_loss: 0.5303
# Epoch 18/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2925 - val_loss: 0.5331
# Epoch 19/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1234 - val_loss: 0.5388
# Epoch 20/20
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.3030 - val_loss: 0.5400
